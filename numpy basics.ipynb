# %%
import numpy as np
a=np.array([1,2])
b=np.array([3,4])
print(np.sum(a))
print(np.sum(a,axis=0))
# Out:
# 3
# 3

# %%
#stacing of arrays
import numpy as np
a=np.array([1,2,3,4])
b=np.array([4,5,6,8])
print(a.dot(b))
# Out:
# 64

# %%
print(a)
# Out:
# [1 2 3 4]

# %%
b=b**2
print(b)
# Out:
# [16 25 36 64]

# %%
a=np.stack((a,b),axis=0)
# Out:
# array([[ 1,  2,  3,  4],
#        [16, 25, 36, 64]])

# %%
#reshape a numpy array 
a=a.reshape((5,2))
print(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-c222f8c6fcb1> in <cell line: 2>()
#       1 #reshape a numpy array
# ----> 2 a=a.reshape((5,2))
#       3 print(a)
#
# ValueError: cannot reshape array of size 4 into shape (5,2)
